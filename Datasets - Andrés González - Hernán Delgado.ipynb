# %% [markdown]
# # Importación de datasets
#
# Comenzamos importando Pandas y Drive, para luego montar la unidad

# %%
import pandas as pd
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Dataset Aerolíneas
#
# Importamos un dataset con datos de Aerolíneas que permiten conocer las demoras en las partidas y arribos, así como aquellas causadas por cuestiones climáticas.
#
# Elegimos este dataset con la idea de que nos permitirá, a lo largo de la cursada, trabajar sobre un volumen de datos suficiente a fin de alcanzar una predicción razonable de las demoras en los aviones según distintos índices.

# %%
# %cd '/content/gdrive/MyDrive/Proyecto DSCH/Aerolineas'
aerolineas = pd.read_csv('Airline_dataset.csv')

print(aerolineas)
# Out:
# /content/gdrive/MyDrive/Proyecto DSCH/Aerolineas
#          Unnamed: 0 FL_DATE  AIRLINE_ID TAIL_NUM  FLIGHT_NUM  ORIGIN_SEQ_ID  \
# 0                 0  8/1/18     19805.0   N956AN      1587.0      1247805.0
# 1                 1  8/1/18     19805.0   N973AN      1588.0      1410702.0
# 2                 2  8/1/18     19805.0    N9006      1590.0      1104205.0
# 3                 3  8/1/18     19805.0   N870NN      1591.0      1484306.0
# 4                 4  8/1/18     19805.0   N9023N      1593.0      1042302.0
# ...             ...     ...         ...      ...         ...            ...
# 1204820     1226363  1/5/20     19977.0   N66831      1598.0      1477104.0
# 1204821     1226364  1/5/20     19977.0   N57111      1597.0      1161802.0
# 1204822     1226365  1/5/20     19977.0   N34455      1592.0      1226603.0
# 1204823     1226366  1/5/20     19977.0   N16234      1591.0      1129202.0
# 1204824     1226367  1/5/20     19977.0   N36444      1588.0      1393007.0
#
# ...

# %% [markdown]
# # Dataset Fútbol Europeo
#
# Importamos un dataset con datos acerca de las incidencias en los partidos de las cinco ligas mas grandes de europa, que permiten conocer tiros al arco, tiros desviados, faltas cometidas, tarjetas, etc.
#
# Entendemos que este dataset puede ser una base de información suficiente y relevante para generar un modelo que pueda predecir comportamientos, por ejemplo cuántas faltas cometerá un jugador durante la siguiente temporada, o cuántas tarjetas recibirá un determinado futbolista durante un determinado período de tiempo.

# %%
# %cd '/content/gdrive/MyDrive/Proyecto DSCH/Futbol'
data_futbol = pd.read_csv('events.csv')
meta_futbol = pd.read_csv('ginf.csv')
diccionario = pd.read_csv('dictionary.txt')

print(diccionario)
# Out:
# /content/gdrive/MyDrive/Proyecto DSCH/Futbol
#          event_type
# 0   0\tAnnouncement
# 1        1\tAttempt
# 2         2\tCorner
# 3           3\tFoul
# 4    4\tYellow card
# ..              ...
# 69        situation
# 70     1\tOpen play
# 71     2\tSet piece
# 72        3\tCorner
# 73     4\tFree kick
#
# [74 rows x 1 columns]

# %% [markdown]
# # Dataset Avistamientos de OVNIs
#
# Importamos un dataset con datos acerca de avistamientos de OVNIs entre 1949 y 2013, incluyendo datos clave como las coordenadas del avistamiento, que forma se reconocía en el cielo y su duración.
#
# Pensamos que dicho dataset nos permitirá crear un modelo predictivo a fin de saber con anticipación en qué épocas del año, en que zonas del planeta e incluso en que años en particular existirá mayor actividad en cuanto a los avistamientos se refiere.

# %%
# %cd '/content/gdrive/MyDrive/Proyecto DSCH/ovnis'
data_ovnis = pd.read_csv('scrubbed.csv')

print(data_ovnis)
# Out:
# /content/gdrive/MyDrive/Proyecto DSCH/ovnis
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# ...
